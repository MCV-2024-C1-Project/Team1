# %%
from data_loader import DataLoader
import matplotlib.pyplot as plt
import cv2

# %%
def plot_image(image):
    '''
    Function to plot images in all scales. 
    image: BGR 
    '''
    # Convert the image to different color spaces
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    lab_image = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    ycrcb_image = cv2.cvtColor(image, cv2.COLOR_BGR2YCrCb)

    # Convert BGR to RGB for displaying with Matplotlib
    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # Plot the images
    fig, axes = plt.subplots(1, 5, figsize=(20, 5))
    axes[0].imshow(rgb_image)
    axes[0].set_title('RGB')
    axes[0].axis('off')

    axes[1].imshow(gray_image, cmap='gray')
    axes[1].set_title('Grayscale')
    axes[1].axis('off')

    axes[2].imshow(hsv_image)
    axes[2].set_title('HSV')
    axes[2].axis('off')

    axes[3].imshow(lab_image)
    axes[3].set_title('Lab')
    axes[3].axis('off')

    axes[4].imshow(ycrcb_image)
    axes[4].set_title('YCrCb')
    axes[4].axis('off')

    plt.show()

# %%
args = {"dataset":"C:/Users/laila/Downloads/BBDD/BBDD"}
DataLoader0 = DataLoader(args)
images = DataLoader0.load_images_from_folder()
plot_image(images[0])

# %%
args = {"dataset":"C:/Users/laila/Downloads/qsd1_w2/qsd1_w1"}
DataLoader1 = DataLoader(args)
QSD1 = DataLoader1.load_images_from_folder()
plot_image(QSD1[0])

# %%
args = {"dataset":"C:/Users/laila/Downloads/qsd2_w2/qsd2_w1"}
DataLoader2 = DataLoader(args)
QSD2 = DataLoader2.load_images_from_folder()
plot_image(QSD2[0])
plot_image(QSD2[1])
plot_image(QSD2[2])
plot_image(QSD2[3])

# %%
# Get dimensions
height, width, channels = QSD1[1].shape

print(f"Width: {width}, Height: {height}")
# Out:
# Width: 1060, Height: 1320

# %%
from feature_extractor import FeatureExtractor
FeatureExtractor1 = FeatureExtractor()
block_size = width//2
blocks,block_histograms = FeatureExtractor1.divide_image_in_blocks(QSD1[0],color_space="Gray",block_size=block_size)
plot_image(blocks[0])

# %%
FeatureExtractor1.plot_histograms_divided(block_histograms)

# %%
blocks,block_histograms = FeatureExtractor1.divide_image_in_blocks(QSD1[0],color_space="Gray",block_size=50)
print(len(block_histograms))
# Out:
# 484

# %%
FeatureExtractor1.plot_histograms_divided(block_histograms)

# %%
FeatureExtractor1.plot_rgb_visualized(QSD1[0])

# %% [markdown]
# # Background Removal

# %%
import numpy as np
import cv2 as cv
 
fgbg = cv.bgsegm.createBackgroundSubtractorMOG()
 
fgmask = fgbg.apply(QSD1[0])
cv.imshow('frame',fgmask)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 4
#       1 import numpy as np
#       2 import cv2 as cv
# ----> 4 fgbg = cv.bgsegm.createBackgroundSubtractorMOG()
#       6 fgmask = fgbg.apply(QSD1[0])
#       7 cv.imshow('frame',fgmask)
#
# AttributeError: module 'cv2' has no attribute 'bgsegm'
